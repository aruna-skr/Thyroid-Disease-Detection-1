# %% [markdown]
# # Import Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, StandardScaler
from imblearn.over_sampling import SMOTE
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import pandas as pd
import logging
import numpy as np

# %%
data=pd.read_csv('Preprocessed_data.csv')

#Dividing target variable from the main dataset

X = data.iloc[: , 0:-1]
Y = data.iloc[: , -1]

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=1)

# %% [markdown]
# # Encoding categorical data
# ## Encoding the Independent Variable

# %%
ordinal_encoder = OrdinalEncoder()
X_train_cat_encoded = pd.DataFrame(ordinal_encoder.fit_transform(X_train.select_dtypes(exclude='number')))
X_train_cat_encoded.columns = X_train.select_dtypes(exclude='number').columns

X_test_cat_encoded = pd.DataFrame(ordinal_encoder.transform(X_test.select_dtypes(exclude='number')))
X_test_cat_encoded.columns = X_test.select_dtypes(exclude='number').columns

# %% [markdown]
# ## Encoding the Independent Variable

# %%
label_encoder = LabelEncoder()
Y_train_cat_encoded= pd.DataFrame(label_encoder.fit_transform(Y_train))
Y_test_cat_encoded = pd.DataFrame(label_encoder.transform(Y_test))

# %% [markdown]
# ## Standardization

# %%
sc = StandardScaler()
X_train_sc=pd.DataFrame(sc.fit_transform(X_train.select_dtypes(exclude='O')))
X_test_sc=pd.DataFrame(sc.transform(X_test.select_dtypes(exclude='O')))

X_train_sc.columns=X_train.select_dtypes(exclude='O').columns
X_test_sc.columns=X_test.select_dtypes(exclude='O').columns

# %% [markdown]
# ## Combining data

# %%
X_train_final=pd.concat([X_train_sc,X_train_cat_encoded],axis=1)
X_test_final=pd.concat([X_test_sc,X_test_cat_encoded],axis=1)

# %% [markdown]
# ## Handling imbalanced Dataset
# ### Since the dataset is small, will use over-sampling: SMOTE technique to balance the data

# %%
X_train_resample,Y_train_resample=SMOTE(random_state=0,k_neighbors=1).fit_resample(X_train_final,Y_train_cat_encoded)
X_test_resample,Y_test_resample=SMOTE(random_state=0,k_neighbors=1).fit_resample(X_test_final,Y_test_cat_encoded)

X_train_resample.shape,X_test_resample.shape,Y_train_resample.shape,Y_test_resample.shape
# Out:
# ((7852, 28), (1476, 28), (7852, 1), (1476, 1))

# %% [markdown]
# ## Feature Selection

# %%
print('Training dataset shape:', X_train_resample.shape, Y_train_resample.shape)
print('Testing dataset shape:', X_test_resample.shape, Y_test_resample.shape)

Y_train_resample_flat = Y_train_resample.to_numpy().ravel()
Y_test_resample_flat = Y_test_resample.to_numpy().ravel()

print('Training dataset shape:', X_train_resample.shape, Y_train_resample_flat.shape)
print('Testing dataset shape:', X_test_resample.shape, Y_test_resample_flat.shape)
# Out:
# Training dataset shape: (7852, 28) (7852, 1)
# Testing dataset shape: (1476, 28) (1476, 1)
# Training dataset shape: (7852, 28) (7852,)
# Testing dataset shape: (1476, 28) (1476,)

# %% [markdown]
# ### Forward selection approach

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth=5)
forward_fs = sfs(rf , k_features=10,forward=True,floating=False,verbose=2,scoring='accuracy',cv=5)
forward_fs = forward_fs.fit(X_train_resample, Y_train_resample_flat)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:   23.7s finished
#
# [2022-05-13 07:34:29] Features: 1/10 -- score: 0.7901158335597027[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:   31.5s finished
#
# [2022-05-13 07:35:01] Features: 2/10 -- score: 0.9687971878838988[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:   29.6s finished
#
# [2022-05-13 07:35:31] Features: 3/10 -- score: 0.9838248995528023[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:   31.8s finished
#
# [2022-05-13 07:36:03] Features: 4/10 -- score: 0.9950328201843119[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   33.5s finished
#
# [2022-05-13 07:36:36] Features: 5/10 -- score: 0.9970706313070906[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:   31.6s finished
#
# [2022-05-13 07:37:08] Features: 6/10 -- score: 0.9980894963247071[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
#
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...

# %%
# Create the Handler for logging records/messages to a file
file_handler = logging.FileHandler("log_file.log")

# %%
#set the format of the log records and the logging level to DEBUG
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG)

# %%
# a function  to create and save logs in the log files
def log(path, file):
    """[Create a log file to record the experiment's logs]
    
    Arguments:
        path {string} -- path to the directory
        file {string} -- file name
    
    Returns:
        [obj] -- [logger that record logs]
    """

    # check if the file exist
    log_file = os.path.join(path, file)

    if not os.path.isfile(log_file):
        open(log_file, "w+").close()

    console_logging_format = "%(levelname)s %(message)s"
    file_logging_format = "%(levelname)s: %(asctime)s: %(message)s"

    # configure logger
    logging.basicConfig(level=logging.INFO, format=console_logging_format)
    logger = logging.getLogger()
    
    # create a file handler for output file
    handler = logging.FileHandler(log_file)

    # set the logging level for log file
    handler.setLevel(logging.INFO)
    
    # create a logging format
    formatter = logging.Formatter(file_logging_format)
    handler.setFormatter(formatter)

    # add the handlers to the logger
    logger.addHandler(handler)

    return logger

# %%
logger = log(path=".",file="log_file.log")

# %%
logger.info("Feature Selection")
# Out:
# 2022-05-13 07:40:31,273 INFO:Feature Selection

# %%
feat_names = list(forward_fs.k_feature_names_)
logger.info("Features {}".format(feat_names))
X_train_new=X_train_resample[['age','sex','TSH', 'TT4', 'FTI', 'on_thyroxine', 'on_antithyroid_medication', 'goitre', 'hypopituitary', 'psych', 'T3_measured']]
X_test_new=X_test_resample[['age','sex','TSH', 'TT4', 'FTI', 'on_thyroxine', 'on_antithyroid_medication', 'goitre', 'hypopituitary', 'psych', 'T3_measured']]
# Out:
# 2022-05-13 07:40:34,028 INFO:Features ['TSH', 'TT4', 'FTI', 'on_thyroxine', 'I131_treatment', 'referral_source']

# %%
#Fitting the Random Forest model
rf_model=rf.fit(X_train_new,Y_train_resample_flat)

logger.info("Traininig Random Forest Model")

#Checking the metrics of Random Forest
def print_Score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        pred=clf.predict(x_train)
        clf_report=pd.DataFrame(classification_report(y_train,pred,output_dict=True))
        print("Train Result:\n===============")
        print(f"Accuracy Score:{accuracy_score(y_train,pred)*100:.2f}%")
        print("---------------------------------")
        print(f"Classification Report:\n{clf_report}")
        print("-----------------------------------")
        print(f"Confusion Matrix:\n{confusion_matrix(y_train,pred)}\n")
        logger.info("Train Result:\n==============="+"\n"+
                    f"Accuracy Score:{accuracy_score(y_train,pred)*100:.2f}%""\n"+
        "---------------------------------"+"\n"+
        f"Classification Report:\n{clf_report}"+"\n"+
        "-----------------------------------"+"\n"+
        f"Confusion Matrix:\n{confusion_matrix(y_train,pred)}\n")
    elif train==False:
        pred=clf.predict(x_test)
        clf_report=pd.DataFrame(classification_report(y_test,pred,output_dict=True))
        print("Test Result:\n===============")
        print(f"Accuracy Score:{accuracy_score(y_test,pred)*100:.2f}%")
        print("---------------------------------")
        print(f"Classification Report:\n{clf_report}")
        print("---------------------------------")
        print(f"Confusion Matrix:\n{confusion_matrix(y_test,pred)}\n")
        
        logger.info("Test Result:\n==============="+"\n"+
        f"Accuracy Score:{accuracy_score(y_test,pred)*100:.2f}%"+"\n"+
        "---------------------------------"+"\n"+
        f"Classification Report:\n{clf_report}"+"\n"+
        "---------------------------------"+"\n"+
        f"Confusion Matrix:\n{confusion_matrix(y_test,pred)}\n")
        
print_Score(rf_model,X_train_new,X_test_new,Y_train_resample_flat,Y_test_resample_flat,train=True)
print_Score(rf_model,X_train_new,X_test_new,Y_train_resample_flat,Y_test_resample_flat,train=False)
# Out:
# 2022-05-13 07:40:41,356 INFO:Traininig Random Forest Model
# 2022-05-13 07:40:41,532 INFO:Train Result:
# ===============
# Accuracy Score:99.81%
# ---------------------------------
# Classification Report:
#                      0            1            2            3  accuracy  \
# precision     0.994428     0.999487     0.998474     1.000000   0.99809
# recall        1.000000     0.992868     1.000000     0.999491   0.99809
# f1-score      0.997206     0.996167     0.999236     0.999745   0.99809
# support    1963.000000  1963.000000  1963.000000  1963.000000   0.99809
#
#              macro avg  weighted avg
# precision     0.998097      0.998097
# recall        0.998090      0.998090
# f1-score      0.998089      0.998089
# support    7852.000000   7852.000000
# -----------------------------------
# Confusion Matrix:
# [[1963    0    0    0]
#  [  11 1949    3    0]
#  [   0    0 1963    0]
#  [   0    1    0 1962]]
#
# 2022-05-13 07:40:41,553 INFO:Test Result:
# ===============
# Accuracy Score:97.76%
# ---------------------------------
# Classification Report:
#                     0           1           2  accuracy    macro avg  \
# precision    0.937143    1.000000    1.000000  0.977642     0.979048
# recall       1.000000    0.991870    0.941057  0.977642     0.977642
# f1-score     0.967552    0.995918    0.969634  0.977642     0.977701
# support    492.000000  492.000000  492.000000  0.977642  1476.000000
#
#            weighted avg
# precision      0.979048
# recall         0.977642
# f1-score       0.977701
# support     1476.000000
# ---------------------------------
# Confusion Matrix:
# [[492   0   0]
#  [  4 488   0]
#  [ 29   0 463]]
# Train Result:
# ===============
# Accuracy Score:99.81%
# ---------------------------------
# Classification Report:
#                      0            1            2            3  accuracy  \
# precision     0.994428     0.999487     0.998474     1.000000   0.99809
# recall        1.000000     0.992868     1.000000     0.999491   0.99809
# f1-score      0.997206     0.996167     0.999236     0.999745   0.99809
# support    1963.000000  1963.000000  1963.000000  1963.000000   0.99809
#
#              macro avg  weighted avg
# precision     0.998097      0.998097
# recall        0.998090      0.998090
# f1-score      0.998089      0.998089
# support    7852.000000   7852.000000
# -----------------------------------
# Confusion Matrix:
# [[1963    0    0    0]
#  [  11 1949    3    0]
#  [   0    0 1963    0]
#  [   0    1    0 1962]]
#
# Test Result:
# ===============
# Accuracy Score:97.76%
# ---------------------------------
# Classification Report:
#                     0           1           2  accuracy    macro avg  \
# precision    0.937143    1.000000    1.000000  0.977642     0.979048
# recall       1.000000    0.991870    0.941057  0.977642     0.977642
# f1-score     0.967552    0.995918    0.969634  0.977642     0.977701
# support    492.000000  492.000000  492.000000  0.977642  1476.000000
#
#            weighted avg
# precision      0.979048
# recall         0.977642
# f1-score       0.977701
# support     1476.000000
# ---------------------------------
# Confusion Matrix:
# [[492   0   0]
#  [  4 488   0]
#  [ 29   0 463]]

# %%
##Hyper parameter tuning
RF=RandomForestClassifier()
model=RF.fit(X_train_new,Y_train_resample_flat)

print_Score(model,X_train_new,X_test_new,Y_train_resample_flat,Y_test_resample_flat,train=True)
print_Score(model,X_train_new,X_test_new,Y_train_resample_flat,Y_test_resample_flat,train=False)
# Out:
# 2022-05-13 07:40:48,779 INFO:Train Result:
# ===============
# Accuracy Score:99.99%
# ---------------------------------
# Classification Report:
#                 0            1            2       3  accuracy    macro avg  \
# precision     1.0     1.000000     0.999491     1.0  0.999873     0.999873
# recall        1.0     0.999491     1.000000     1.0  0.999873     0.999873
# f1-score      1.0     0.999745     0.999745     1.0  0.999873     0.999873
# support    1963.0  1963.000000  1963.000000  1963.0  0.999873  7852.000000
#
#            weighted avg
# precision      0.999873
# recall         0.999873
# f1-score       0.999873
# support     7852.000000
# -----------------------------------
# Confusion Matrix:
# [[1963    0    0    0]
#  [   0 1962    1    0]
#  [   0    0 1963    0]
#  [   0    0    0 1963]]
#
# 2022-05-13 07:40:48,802 INFO:Test Result:
# ===============
# Accuracy Score:98.10%
# ---------------------------------
# Classification Report:
#                     0           1           2  accuracy    macro avg  \
# precision    0.946154    1.000000    1.000000   0.98103     0.982051
# recall       1.000000    0.995935    0.947154   0.98103     0.981030
# f1-score     0.972332    0.997963    0.972860   0.98103     0.981052
# support    492.000000  492.000000  492.000000   0.98103  1476.000000
#
#            weighted avg
# precision      0.982051
# recall         0.981030
# f1-score       0.981052
# support     1476.000000
# ---------------------------------
# Confusion Matrix:
# [[492   0   0]
#  [  2 490   0]
#  [ 26   0 466]]
# Train Result:
# ===============
# Accuracy Score:99.99%
# ---------------------------------
# Classification Report:
#                 0            1            2       3  accuracy    macro avg  \
# precision     1.0     1.000000     0.999491     1.0  0.999873     0.999873
# recall        1.0     0.999491     1.000000     1.0  0.999873     0.999873
# f1-score      1.0     0.999745     0.999745     1.0  0.999873     0.999873
# support    1963.0  1963.000000  1963.000000  1963.0  0.999873  7852.000000
#
#            weighted avg
# precision      0.999873
# recall         0.999873
# f1-score       0.999873
# support     7852.000000
# -----------------------------------
# Confusion Matrix:
# [[1963    0    0    0]
#  [   0 1962    1    0]
#  [   0    0 1963    0]
#  [   0    0    0 1963]]
#
# Test Result:
# ===============
# Accuracy Score:98.10%
# ---------------------------------
# Classification Report:
#                     0           1           2  accuracy    macro avg  \
# precision    0.946154    1.000000    1.000000   0.98103     0.982051
# recall       1.000000    0.995935    0.947154   0.98103     0.981030
# f1-score     0.972332    0.997963    0.972860   0.98103     0.981052
# support    492.000000  492.000000  492.000000   0.98103  1476.000000
#
#            weighted avg
# precision      0.982051
# recall         0.981030
# f1-score       0.981052
# support     1476.000000
# ---------------------------------
# Confusion Matrix:
# [[492   0   0]
#  [  2 490   0]
#  [ 26   0 466]]

# %%
## Randomized Search CV

#No of trees in Random Forest
n_estimators=[int(x) for x in np.linspace(start=200,stop=2000,num=10)]
#No of features consider at every split
max_features=['auto','sqrt','log2']
#maximum no of levels in trees
max_depth=[int(x) for x in np.linspace(10,1000,10)]
#minimum no of samples required to split a node
min_samples_split=[1,3,4,5,7,9]
#minimum samples leafs required at each leaf node
min_sample_leafs=[1,2,4,6,8]

#create random gird
random_grid={'n_estimators':n_estimators,
'max_features':max_features,
'max_depth':max_depth,
'min_samples_split':min_samples_split,
'min_samples_leaf':min_sample_leafs,
'criterion':['entropy','gini']}
print(random_grid)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [1, 3, 4, 5, 7, 9], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
rcv=RandomizedSearchCV(estimator=RF,param_distributions=random_grid,n_iter=100,cv=3,verbose=2,random_state=0,n_jobs=-1)

rcv.fit(X_train_new,Y_train_resample_flat)

logger.info("Use Randomized Search CV")

# %%
rcv.best_estimator_
logger.info(rcv.best_estimator_)

# %%
best_random_grid=rcv.best_estimator_
logger.info("Result with best estimetors")
print_Score(best_random_grid,X_train_new,X_test_new,Y_train_resample_flat,Y_test_resample_flat,train=False)
# Out:
# 2021-12-29 14:49:29,009 INFO:Result with best estimetors
# 2021-12-29 14:49:29,201 INFO:Test Result:
# ===============
# Accuracy Score:97.97%
# ---------------------------------
# Classification Report:
#                     0           1           2  accuracy    macro avg  \
# precision    0.942529    1.000000    1.000000  0.979675     0.980843
# recall       1.000000    0.995935    0.943089  0.979675     0.979675
# f1-score     0.970414    0.997963    0.970711  0.979675     0.979696
# support    492.000000  492.000000  492.000000  0.979675  1476.000000
#
#            weighted avg
# precision      0.980843
# recall         0.979675
# f1-score       0.979696
# support     1476.000000
# ---------------------------------
# Confusion Matrix:
# [[492   0   0]
#  [  2 490   0]
#  [ 28   0 464]]
# Test Result:
# ===============
# Accuracy Score:97.97%
# ---------------------------------
# Classification Report:
#                     0           1           2  accuracy    macro avg  \
# precision    0.942529    1.000000    1.000000  0.979675     0.980843
# recall       1.000000    0.995935    0.943089  0.979675     0.979675
# f1-score     0.970414    0.997963    0.970711  0.979675     0.979696
# support    492.000000  492.000000  492.000000  0.979675  1476.000000
#
#            weighted avg
# precision      0.980843
# recall         0.979675
# f1-score       0.979696
# support     1476.000000
# ---------------------------------
# Confusion Matrix:
# [[492   0   0]
#  [  2 490   0]
#  [ 28   0 464]]

# %%
param_grid = {
    'criterion': [rcv.best_params_['criterion']],
    'max_depth': [rcv.best_params_['max_depth']],
    'max_features': [rcv.best_params_['max_features']],
    'min_samples_leaf': [rcv.best_params_['min_samples_leaf'], 
                         rcv.best_params_['min_samples_leaf']+2, 
                         rcv.best_params_['min_samples_leaf'] + 4],
    'min_samples_split': [rcv.best_params_['min_samples_split'] - 2,
                          rcv.best_params_['min_samples_split'] - 1,
                          rcv.best_params_['min_samples_split'], 
                          rcv.best_params_['min_samples_split'] +1,
                          rcv.best_params_['min_samples_split'] + 2],
    'n_estimators': [rcv.best_params_['n_estimators'] - 200, rcv.best_params_['n_estimators'] - 100, 
                     rcv.best_params_['n_estimators'], 
                     rcv.best_params_['n_estimators'] + 100, rcv.best_params_['n_estimators'] + 200]
}

# %%
print(param_grid)
logger.info(f"Parameter Grid: {param_grid}")
# Out:
# 2021-12-29 14:49:29,245 INFO:Parameter Grid: {'criterion': ['entropy'], 'max_depth': [560], 'max_features': ['sqrt'], 'min_samples_leaf': [1, 3, 5], 'min_samples_split': [7, 8, 9, 10, 11], 'n_estimators': [200, 300, 400, 500, 600]}
# {'criterion': ['entropy'], 'max_depth': [560], 'max_features': ['sqrt'], 'min_samples_leaf': [1, 3, 5], 'min_samples_split': [7, 8, 9, 10, 11], 'n_estimators': [200, 300, 400, 500, 600]}

# %%
grid_search=GridSearchCV(estimator=RF,param_grid=param_grid,cv=10,n_jobs=1,verbose=2)
grid_search.fit(X_train_new,Y_train_resample_flat)
logger.info("Grid Search CV: ")
# Out:
# Fitting 10 folds for each of 75 candidates, totalling 750 fits
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200, total=   2.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200, total=   2.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200, total=   2.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200, total=   1.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200, total=   2.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200, total=   2.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200, total=   2.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200, total=   2.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200, total=   2.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=200, total=   2.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300, total=   3.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300, total=   3.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300, total=   2.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300, total=   3.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300, total=   2.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300, total=   3.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300, total=   3.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300, total=   3.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300, total=   3.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=300, total=   3.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400, total=   4.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400, total=   4.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400, total=   4.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400, total=   3.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400, total=   4.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400, total=   4.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400, total=   4.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400, total=   4.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400, total=   4.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=400, total=   4.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500, total=   5.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500, total=   5.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500, total=   5.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500, total=   5.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500, total=   4.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500, total=   6.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500, total=   5.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500, total=   5.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500, total=   5.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=500, total=   5.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600, total=   5.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600, total=   6.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600, total=   6.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600, total=   6.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600, total=   6.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600, total=   6.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600, total=   6.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600, total=   7.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600, total=   5.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=600, total=   6.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200, total=   1.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200, total=   1.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200, total=   1.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200, total=   2.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200, total=   2.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200, total=   2.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200, total=   2.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200, total=   2.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200, total=   2.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=200, total=   2.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300, total=   2.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300, total=   3.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300, total=   2.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300, total=   2.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300, total=   3.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300, total=   3.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300, total=   3.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300, total=   3.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300, total=   3.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=300, total=   2.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400, total=   4.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400, total=   3.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400, total=   4.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400, total=   4.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400, total=   4.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400, total=   4.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400, total=   4.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400, total=   4.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400, total=   4.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=400, total=   4.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   5.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   5.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   4.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   5.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   5.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   5.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   4.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   5.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   5.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=500, total=   5.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600, total=   6.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600, total=   5.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600, total=   6.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600, total=   6.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600, total=   5.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600, total=   5.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600, total=   6.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600, total=   5.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600, total=   5.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=600, total=   6.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200, total=   2.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200, total=   2.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200, total=   2.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200, total=   2.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200, total=   2.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200, total=   2.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200, total=   2.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200, total=   1.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200, total=   2.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=200, total=   1.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300, total=   3.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300, total=   3.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300, total=   3.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300, total=   3.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300, total=   3.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300, total=   3.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300, total=   3.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300, total=   3.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300, total=   3.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=300, total=   2.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400, total=   4.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400, total=   3.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400, total=   3.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400, total=   4.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400, total=   3.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400, total=   4.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400, total=   4.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400, total=   4.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400, total=   4.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=400, total=   4.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500, total=   4.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500, total=   4.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500, total=   4.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500, total=   5.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500, total=   5.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500, total=   5.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500, total=   4.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500, total=   6.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500, total=   5.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=500, total=   5.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600, total=   6.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600, total=   6.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600, total=   6.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600, total=   5.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600, total=   6.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600, total=   6.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600, total=   6.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600, total=   6.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600, total=   6.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600, total=   6.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, total=   2.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, total=   2.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, total=   2.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, total=   2.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, total=   2.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, total=   1.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, total=   2.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, total=   3.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, total=   2.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, total=   3.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, total=   5.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, total=   5.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, total=   4.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, total=   5.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, total=   5.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, total=   4.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, total=   4.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, total=   4.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, total=   4.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, total=   5.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, total=   6.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, total=   6.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, total=   5.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, total=   6.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, total=   6.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, total=   6.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, total=   6.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, total=   6.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, total=   6.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, total=   6.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   8.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   7.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   7.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   8.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   7.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   8.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   9.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   8.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   6.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, total=   7.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600, total=   9.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600
# ...
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   8.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   7.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500, total=   7.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600, total=   9.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600, total=   9.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600, total=   9.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600, total=   8.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600, total=   8.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600, total=   9.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600, total=   9.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600, total=   9.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600, total=   9.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600, total=   9.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200, total=   3.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200, total=   3.0s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200, total=   2.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200, total=   3.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200, total=   3.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200, total=   2.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200, total=   3.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200, total=   3.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200, total=   3.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=200, total=   3.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300, total=   4.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300, total=   4.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300, total=   4.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300, total=   4.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300, total=   4.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300, total=   3.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300, total=   4.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300, total=   4.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300, total=   4.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=300, total=   4.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400, total=   6.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400, total=   5.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400, total=   5.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400, total=   5.8s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400, total=   6.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400, total=   5.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400, total=   5.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400, total=   6.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400, total=   6.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=400, total=   6.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500, total=   7.9s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500, total=   8.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500, total=   8.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500, total=   7.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500, total=   6.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500, total=   7.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500, total=   8.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500, total=   7.7s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500, total=   8.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=500, total=   7.4s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600, total=   9.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600, total=   9.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600, total=   9.3s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600, total=   9.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600, total=   8.5s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600, total=   9.6s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600, total=   9.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600, total=   9.2s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600, total=  10.1s
# [CV] criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600
# [CV]  criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=600, total=   9.2s
# [Parallel(n_jobs=1)]: Done 750 out of 750 | elapsed: 72.4min finished
# 2021-12-29 16:02:02,281 INFO:Grid Search CV:

# %%
best_grid=grid_search.best_estimator_
best_grid
logger.info(f"Best Grid: {best_grid}")
# Out:
# 2021-12-29 16:02:02,311 INFO:Best Grid: RandomForestClassifier(criterion='entropy', max_depth=560, max_features='sqrt',
#                        min_samples_split=7, n_estimators=500)

# %%
logger.info("Result with Best Grid: ")
print_Score(best_grid,X_train_new,X_test_new,Y_train_resample_flat,Y_test_resample_flat,train=False)
# Out:
# 2021-12-29 16:02:02,342 INFO:Result with Best Grid:
# 2021-12-29 16:02:02,596 INFO:Test Result:
# ===============
# Accuracy Score:98.10%
# ---------------------------------
# Classification Report:
#                     0           1           2  accuracy    macro avg  \
# precision    0.946154    1.000000    1.000000   0.98103     0.982051
# recall       1.000000    0.995935    0.947154   0.98103     0.981030
# f1-score     0.972332    0.997963    0.972860   0.98103     0.981052
# support    492.000000  492.000000  492.000000   0.98103  1476.000000
#
#            weighted avg
# precision      0.982051
# recall         0.981030
# f1-score       0.981052
# support     1476.000000
# ---------------------------------
# Confusion Matrix:
# [[492   0   0]
#  [  2 490   0]
#  [ 26   0 466]]
# Test Result:
# ===============
# Accuracy Score:98.10%
# ---------------------------------
# Classification Report:
#                     0           1           2  accuracy    macro avg  \
# precision    0.946154    1.000000    1.000000   0.98103     0.982051
# recall       1.000000    0.995935    0.947154   0.98103     0.981030
# f1-score     0.972332    0.997963    0.972860   0.98103     0.981052
# support    492.000000  492.000000  492.000000   0.98103  1476.000000
#
#            weighted avg
# precision      0.982051
# recall         0.981030
# f1-score       0.981052
# support     1476.000000
# ---------------------------------
# Confusion Matrix:
# [[492   0   0]
#  [  2 490   0]
#  [ 26   0 466]]

# %%
#Now, will convert our final model into pickle file

import pickle

pickle_out=open('Thyroid_model.pkl','wb')
pickle.dump(grid_search,pickle_out)
pickle_out.close()
logger.info("Random Forest Model with Grid Search Saved in Pickle")
# Out:
# 2021-12-29 16:02:02,667 INFO:Random Forest Model with Grid Search Saved in Pickle
